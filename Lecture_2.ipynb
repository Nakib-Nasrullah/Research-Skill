# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/Research-Skill/blob/main/Lecture_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**

# %%
print("Hello Word")
# Out:
# Hello Word

# %% [markdown]
# # **Variable**

# %%
#Create variable
name = "Nakib"
age = 27 #int
is_student = True #boolian
height = 5.8 #float
print("Name:", name)
print("Age:",age)
print("Student status:",is_student)
print("Height:",height)
# Out:
# Name: Nakib
# Age: 27
# Student status: True
# Height: 5.8

# %%
print(type(name))
print(type(age))
print(type(is_student))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %%
a = 40
b = 5
print(a + b) #Addition
print(a - b) #Subtraction
print(a * b) #Multiplication
print(a / b) #Division
print(a % b) #Modulus
print(a // b)#Floor
print(a ** b)# Exponential
# Out:
# 45
# 35
# 200
# 8.0
# 0
# 8
# 102400000

# %%
from typing import LiteralString
first = "Hello"
last = "World"
#Concatenation
full = first + " " + last
print(full)
#Repetition
repeted = first * 3
print(repeted)
#Length
print(len(full))
# Out:
# Hello World
# HelloHelloHello
# 11

# %% [markdown]
# # **String**

# %%
s1 = "Hello"
s2 = "World"
#Accessing characters
text = "Python"
print(text[0]) #P
print(text[-1]) #n

#Slicing
text = "Python"
print(text[0:3]) #pyt
print(text[2:])
print(text[:4])

#Concatenation
a = "Hello"
b = "World"
result = a + " " + b
print(result)

#Repetition
print("Hi " *3)

#length
len("Python")

#Convert case
print("Python".upper())
print("Hello".lower())

#Replace text
"Hello Python".replace("Python", "World !!")
# Out:
# P
# n
# Pyt
# thon
# Pyth
# Hello World
# Hi Hi Hi
# PYTHON
# hello
# 'Hello World !!'

# %% [markdown]
# # **Data Stracture**

# %%
# Creating a list
fruits = ["apple", "banana", "orange", "mango","pineapple"]
# Accessing elements (indexing starts at 0)
print(fruits[0])       # apple
print(fruits[1])       # banana
# Negative indexing (counts from the end)
print(fruits[-1])      # pineapple
# Slicing lists
print(fruits[1:4])     # ['banana', 'orange’]
# Changing an element
fruits[1] = "grape"
print(fruits)          # ['apple', 'grape', 'orange', 'mango']
# Out:
# apple
# banana
# pineapple
# ['banana', 'orange', 'mango']
# ['apple', 'grape', 'orange', 'mango', 'pineapple']

# %%
#Adding Elements in List
fruits = ["apple", "banana"]
fruits.append("orange")    # Add to end ["apple", "banana", "orange"]
fruits.insert(1, "mango")  # Insert at position
print(fruits)  # ['apple', 'mango', 'banana', 'orange']
# Out:
# ['apple', 'mango', 'banana', 'orange']

# %%
#Removing Elements in List
fruits = ["apple", "mango", "banana", "orange"]
fruits.remove("mango")    # Remove by value, updated list: apple, banana, orange
popped = fruits.pop()    # Remove & return last item, apple, banana
print(popped) # orange
print(fruits) # ['apple', 'banana']
# Out:
# orange
# ['apple', 'banana']

# %%
#organinzing list
fruits = ["orange", "apple", "mango", "banana"]
fruits.sort() # Alphabetical order
print(fruits) # ['apple', 'banana', 'mango', 'orange’]
fruits.reverse() # Reverse order
print(fruits) # ['orange', 'mango', 'banana', 'apple']
# Out:
# ['apple', 'banana', 'mango', 'orange']
# ['orange', 'mango', 'banana', 'apple']

# %%
# Creating a dictionary key:value
student = {
"name": "Fahim",
"age": 21,
"university": "AMU",
"courses": ["Python", "Data Science", "Web Development"]}
# Accessing values using keys
print(student["name"])      # Fahim
print(student["courses"][0])  # Python
# Adding or modifying items
student["phone"] = "01716602312"
student["age"] = 22
# Checking if a key exists
if "email" in student:
  print("Email found")
else:
  print("No email found")   # No email found
# Out:
# Fahim
# Python
# No email found

# %%
# Creating a tuple
coordinates = (10.5, 20.8)
rgb_color = (255, 0, 128)
# Accessing elements
print(coordinates[0])    # 10.5
print(rgb_color[2])      # 128
# Attempting to change (will cause error)
# rgb_color[0] = 200  # TypeError!
# Length of tuple
print(len(rgb_color))    # 3
# Out:
# 10.5
# 128
# 3

# %%
# Tuple with different data types
mixed = ("Dhaka", 23.8, True, 2023)
# Single-item tuple needs a comma
single = (42,)  # Without comma: just an int
print(mixed)
print(single)
# Out:
# ('Dhaka', 23.8, True, 2023)
# (42,)

# %%
# Creating a set
fruits = {"apple", "banana", "orange", "apple"}
print(fruits)  # {'orange', 'banana', 'apple'} (no duplicates)
# Adding elements
fruits.add("mango")
fruits.update(["grape", "kiwi"])
print(fruits)
# Removing elements
fruits.remove("banana")  # Raises error if not found
fruits.discard("pear")
# Set operations
bangladeshi_fruits = {"mango", "jackfruit", "banana"}
imported_fruits = {"apple", "kiwi", "banana"}
# Union (all elements from both sets)
all_fruits = bangladeshi_fruits | imported_fruits
print(all_fruits)
# Intersection (common elements)
common = bangladeshi_fruits & imported_fruits  # {'banana'}
print(common)
# Out:
# {'apple', 'orange', 'banana'}
# {'grape', 'banana', 'mango', 'kiwi', 'apple', 'orange'}
# {'apple', 'kiwi', 'mango', 'banana', 'jackfruit'}
# {'banana'}
