# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/Research-Skill/blob/main/Data_Sciennce_Class9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science class : KNN, Decisionn Tress & Random Forest
#
# #Project Goal:
# **Predict whether a patient  has diabetes on medical measurments.**
# #Dataset:
# #Name :** Pima Indians Diabetes Dataset
# #Samples:** 768 patients.
# #Features:** 8 medical measurements.
# Taget: Outcome (0 =No Diabetes, 1= Has Diabetes)

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/Datasets/diabetes.csv')
print("Dataset loaded successfully!!")
print(f"\n Dataset shape: {df.shape}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset loaded successfully!!
#
#  Dataset shape: (768, 9)
